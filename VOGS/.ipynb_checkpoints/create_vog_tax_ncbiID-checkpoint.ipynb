# %%
import pandas as pd
vogs_to_seqs = {}

# %%
for line in open('/Users/williamharrigan/Desktop/Github/protein-seq-contact-sites/VOGS/vog.species.tsv'):
    data = line.split("\t")
    vogs_to_seqs[data[0]] = set([data[1]])
    
    

#data

# %%
vogs_to_seqs.keys()
# Out:
# dict_keys(['#species name', 'Vibrio phage qdvp001', 'Rhodococcus phage E3', 'Enterobacteria phage ES18', 'Synechococcus phage S-CRM01', 'Stenotrophomonas phage phiSHP2', 'Bdellovibrio phage phi1402', 'Enterobacteria phage phiP27', 'Clostridium phage phiCP13O', 'Clostridium phage phiCP34O', 'Chlamydia phage 2', 'Salmonella phage 7-11', 'Phietavirus ETA (Bacteriophage phi ETA)', 'Enterobacteria phage PRD1', 'Vibrio phage CP-T1 (vB_VchM-CP-T1)', 'Streptomyces phage VWB', 'Rhizobium phage 16-3', 'Psychrobacter phage Psymv2', 'Bacillus phage SPP1', 'uncultured phage WW-nAnB', 'Escherichia phage G4', 'Escherichia phage St-1', 'Escherichia phage alpha3', 'Spiromicrovirus SpV4', 'Salmonella phage IKe', 'Escherichia phage If1', 'Lineavirus I22', 'Pseudomonas phage Pf3', 'Mycobacterium phage Dori', 'Bacteroides phage B124-14', 'Rhodobacter phage RcapMu', 'Vibrio phage VCY-phi', 'Nocardia phage NBR1', 'Rhodococcus phage REQ1', 'Rhodococcus phage REQ2', 'Rhodococcus phage REQ3', 'Rhodococcus phage RRH1', 'Sulfolobus virus STSV2', 'Escherichia phage TL-2011b', 'Thermoanaerobacterium phage THSA-485A', 'Bdellovibrio phage phi1422 (vB_BbaM-phi1422)', 'Pectobacterium phage ZF40 (vB_PcaM-ZF40)', 'Vibrio phage vB_VchM-138', 'Pseudomonas phage phi297', 'Erwinia phage PEp14', 'Rhodobacter phage RcapNL', 'Cronobacter phage vB_CsaP_GAP52', 'Lactococcus phage ul36', 'Staphylococcus phage StB20', 'Clostridium phage phi8074-B1', 'Salmonella phage SPN3UB', 'Enterobacteria phage mEp460', 'Sphingomonas phage PAU', 'Ralstonia phage RSS0', 'Weissella phage phiYS61', 'Pseudomonas phage Lu11', 'Cronobacter phage phiES15', 'Vibrio phage VvAW1', 'Salmonella phage vB_SosS_Oslo', 'Halocynthia phage JM-2012', 'Croceibacter phage P2559S', 'Marinomonas phage P12026', 'Salmonella phage SSU5', 'Clostridium phage PhiS63', 'Xanthomonas citri phage CP2', 'Pseudomonas phage phi8', 'Streptococcus phage MM1', 'Lactobacillus phage phiAQ113', 'Rhizobium phage RHEph10', 'Enterobacteria phage SfI', 'Pseudomonas phage JBD25', 'Acinetobacter phage phiAC-1', 'Clostridium phage c-st', 'Lactobacillus phage LL-H', 'Pseudomonas phage AF', 'Lactococcus phage phiLC3', 'Streptococcus phage phiNJ2', 'Streptococcus phage EJ-1', 'Lactobacillus phage phiadh', 'Sulfolobales Mexican rudivirus 1 (SMR1)', 'Streptococcus phage phiBHN167', 'Vibrio phage VfO3K6 (Bacteriophage VfO3K6)', 'Vibrio phage VfO4K68 (Bacteriophage VfO4K68)', 'Villovirus Vf33 (Bacteriophage Vf33)', 'Vibrio phage Vf12', 'Serratia phage Eta', 'Pelagibacter phage HTVC008M', 'Pelagibacter phage HTVC010P', 'Sulfolobales Mexican fusellovirus 1 (SMF1)', 'Clostridium phage vB_CpeS-CP51', 'Bacillus phage vB_BanS-Tsamsa', 'Croceibacter phage P2559Y', 'Cellulophaga phage phi12:2', 'Cellulophaga phage phi46:1', 'Cellulophaga phage phi12a:1', 'Cellulophaga phage phi39:1', 'Vibrio phage VFJ', 'Stenotrophomonas phage SMA7', 'Pseudomonas phage phi13', 'Stenotrophomonas phage SMA6', 'Sulfolobus monocaudavirus SMV1', 'Ralstonia phage RSS30', 'Thermus phage phi OH2', 'Ralstonia phage RSS20', 'Caulobacter phage Cr30', 'Marine gokushovirus', 'Streptococcus phage 20617', 'Lactobacillus prophage Lj965', 'Lactobacillus prophage Lj771', 'Lactobacillus prophage Lj928', 'Lactobacillus phage phiJB', 'Staphylococcus phage phiRS7', 'Shigella phage SfIV', 'Rhizobium phage vB_RleS_L338C', 'Vibrio phage SHOU24', 'Arthrobacter phage vB_ArS-ArV2', 'Lactobacillus phage phi jlb1', 'Enterococcus phage IME-EFm1', 'Streptococcus phage DCC1738', 'Streptococcus phage K13', 'Streptococcus phage IC1', 'Pseudomonas phage vB_PaeP_Tr60_Ab31', 'Uncultured phage WW-nAnB strain 2', 'Uncultured phage WW-nAnB strain 3', 'Pseudomonas phage phi2', 'Bdellovibrio phage phiMH2K', 'Vibrio phage CHOED', 'Geobacillus phage GBK2', 'Listeria phage LP-030-3', 'Shewanella sp. phage 1/4', 'Shewanella sp. phage 1/40', 'Shewanella sp. phage 1/41', 'Shewanella sp. phage 1/44', 'Shewanella sp. phage 3/49', 'Ralstonia phage 1 NP-2014', 'Vibrio phage PVA1', 'Ralstonia phage RS138', 'Enterococcu ...
